# %%
import numpy as np

# %%
# with open('example-outputs/pred_results.npy', 'rb') as f:
#     npy = np.load(f.read())

# %%
npy = np.load('example-outputs/pred_results.npy')

# %%
npy
# Out:
# array([0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999994,
#        0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995, 0.9999995,
# ...

# %%
npy.shape
# Out:
# (278,)

# %%
# Out:
# 0.9999995
